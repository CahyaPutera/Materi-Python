# %% [markdown]
# 1. Cek outlier tiap feature.
# 2. Misal tidak ada outlier, maka kita scaling pd seluruh feature kecuali target.

# %%
import pandas as pd
import numpy as np

# %%
# for standardize / normalisasi data
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import MaxAbsScaler
from sklearn.preprocessing import RobustScaler
from sklearn.preprocessing import Normalizer
from sklearn.preprocessing import Binarizer

# %%
# open data
df = pd.read_csv('melb_data.csv')
df.head()
# Out:
#        Suburb           Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford      85 Turner St      2    h  1480000.0      S  Biggin
# 1  Abbotsford   25 Bloomburg St      2    h  1035000.0      S  Biggin
# 2  Abbotsford      5 Charles St      3    h  1465000.0     SP  Biggin
# 3  Abbotsford  40 Federation La      3    h   850000.0     PI  Biggin
# 4  Abbotsford       55a Park St      4    h  1600000.0     VB  Nelson
#
#         Date  Distance  Postcode  ...  Bathroom  Car  Landsize  BuildingArea  \
# 0  3/12/2016       2.5    3067.0  ...       1.0  1.0     202.0           NaN
# 1  4/02/2016       2.5    3067.0  ...       1.0  0.0     156.0          79.0
# 2  4/03/2017       2.5    3067.0  ...       2.0  0.0     134.0         150.0
# 3  4/03/2017       2.5    3067.0  ...       2.0  1.0      94.0           NaN
# 4  4/06/2016       2.5    3067.0  ...       1.0  2.0     120.0         142.0
#
#    YearBuilt  CouncilArea Lattitude  Longtitude             Regionname  \
# ...

# %%
df_test = df[['Price', 'Distance', 'Car', 'Landsize', 'Rooms', 'Bedroom2', 'Bathroom']]
df_test.head()
# Out:
#        Price  Distance  Car  Landsize  Rooms  Bedroom2  Bathroom
# 0  1480000.0       2.5  1.0     202.0      2       2.0       1.0
# 1  1035000.0       2.5  0.0     156.0      2       2.0       1.0
# 2  1465000.0       2.5  0.0     134.0      3       3.0       2.0
# 3   850000.0       2.5  1.0      94.0      3       3.0       2.0
# 4  1600000.0       2.5  2.0     120.0      4       3.0       1.0

# %% [markdown]
# ### Standard Scaler

# %% [markdown]
# Digunakan pada data yang berdistribusi normal dan jika data cenderung tidak normal, Standard Scaler akan memaksa data berdistribusi normal.

# %%
SScaler = StandardScaler()
Prize_scl = SScaler.fit_transform(df_test[['Price']])
df_test['Prize Std Scl'] = Prize_scl
# Out:
# C:\Users\Admin\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
df_test.head()
# Out:
#        Price  Distance  Car  Landsize  Rooms  Bedroom2  Bathroom  \
# 0  1480000.0       2.5  1.0     202.0      2       2.0       1.0
# 1  1035000.0       2.5  0.0     156.0      2       2.0       1.0
# 2  1465000.0       2.5  0.0     134.0      3       3.0       2.0
# 3   850000.0       2.5  1.0      94.0      3       3.0       2.0
# 4  1600000.0       2.5  2.0     120.0      4       3.0       1.0
#
#    Prize Std Scl
# 0       0.632448
# 1      -0.063640
# 2       0.608984
# 3      -0.353025
# 4       0.820157

# %%
df_test['Price Std Scl 2'] = StandardScaler().fit_transform(df_test[['Price']])
# Out:
# C:\Users\Admin\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df_test.head()
# Out:
#        Price  Distance  Car  Landsize  Rooms  Bedroom2  Bathroom  \
# 0  1480000.0       2.5  1.0     202.0      2       2.0       1.0
# 1  1035000.0       2.5  0.0     156.0      2       2.0       1.0
# 2  1465000.0       2.5  0.0     134.0      3       3.0       2.0
# 3   850000.0       2.5  1.0      94.0      3       3.0       2.0
# 4  1600000.0       2.5  2.0     120.0      4       3.0       1.0
#
#    Prize Std Scl  Price Std Scl 2
# 0       0.632448         0.632448
# 1      -0.063640        -0.063640
# 2       0.608984         0.608984
# 3      -0.353025        -0.353025
# 4       0.820157         0.820157

# %% [markdown]
# ### MinMax Scaler

# %% [markdown]
# Minmax Scaler digunakan pada kondisi feature yang tidak ada outliers dan dipakai sebagai cara pertama dalam proses Standardize feature. Bekerja dengan baik jika datanya tidak ada outlier. Karena MinMax Scaler sensitif dengan outlier. MinMax Scaler tidak mengintervensi data agar berdistribusi normal hanya merubah scale-nya saja.

# %%
df_test['Price MinMax Sc'] = MinMaxScaler().fit_transform(df_test[['Price']])
# Out:
# C:\Users\Admin\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df_test.head()
# Out:
#        Price  Distance  Car  Landsize  Rooms  Bedroom2  Bathroom  \
# 0  1480000.0       2.5  1.0     202.0      2       2.0       1.0
# 1  1035000.0       2.5  0.0     156.0      2       2.0       1.0
# 2  1465000.0       2.5  0.0     134.0      3       3.0       2.0
# 3   850000.0       2.5  1.0      94.0      3       3.0       2.0
# 4  1600000.0       2.5  2.0     120.0      4       3.0       1.0
#
#    Prize Std Scl  Price Std Scl 2  Price MinMax Sc
# 0       0.632448         0.632448         0.156478
# 1      -0.063640        -0.063640         0.106562
# 2       0.608984         0.608984         0.154795
# 3      -0.353025        -0.353025         0.085810
# 4       0.820157         0.820157         0.169938

# %% [markdown]
# ### MaxAbs Scaler

# %% [markdown]
# MaxAbs dipakai ketika datanya tidak ada outlier

# %%
df_test['Price MaxAbs Scl'] = MaxAbsScaler().fit_transform(df_test[['Price']])
# Out:
# C:\Users\Admin\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df_test.head()
# Out:
#        Price  Distance  Car  Landsize  Rooms  Bedroom2  Bathroom  \
# 0  1480000.0       2.5  1.0     202.0      2       2.0       1.0
# 1  1035000.0       2.5  0.0     156.0      2       2.0       1.0
# 2  1465000.0       2.5  0.0     134.0      3       3.0       2.0
# 3   850000.0       2.5  1.0      94.0      3       3.0       2.0
# 4  1600000.0       2.5  2.0     120.0      4       3.0       1.0
#
#    Prize Std Scl  Price Std Scl 2  Price MinMax Sc  Price MaxAbs Scl
# 0       0.632448         0.632448         0.156478          0.164444
# 1      -0.063640        -0.063640         0.106562          0.115000
# 2       0.608984         0.608984         0.154795          0.162778
# 3      -0.353025        -0.353025         0.085810          0.094444
# 4       0.820157         0.820157         0.169938          0.177778

# %% [markdown]
# ### Robust Scaler

# %% [markdown]
# Robust Scaler di pakai jika feature memiliki data *Outlier*, karena scaler ini *tidak mendasarkan rumusnya dengan mean atau standar deviasi*. Scaler ini dasar teorinya menggunakan *IQR* sehingga lebih tahan (robust) dengan adanya outlier.

# %%
df_test['Price Robust Scl'] = RobustScaler().fit_transform(df_test[['Price']])
# Out:
# C:\Users\Admin\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df_test.head()
# Out:
#        Price  Distance  Car  Landsize  Rooms  Bedroom2  Bathroom  \
# 0  1480000.0       2.5  1.0     202.0      2       2.0       1.0
# 1  1035000.0       2.5  0.0     156.0      2       2.0       1.0
# 2  1465000.0       2.5  0.0     134.0      3       3.0       2.0
# 3   850000.0       2.5  1.0      94.0      3       3.0       2.0
# 4  1600000.0       2.5  2.0     120.0      4       3.0       1.0
#
#    Prize Std Scl  Price Std Scl 2  Price MinMax Sc  Price MaxAbs Scl  \
# 0       0.632448         0.632448         0.156478          0.164444
# 1      -0.063640        -0.063640         0.106562          0.115000
# 2       0.608984         0.608984         0.154795          0.162778
# 3      -0.353025        -0.353025         0.085810          0.094444
# 4       0.820157         0.820157         0.169938          0.177778
#
#    Price Robust Scl
# 0          0.848529
# 1          0.194118
# 2          0.826471
# 3         -0.077941
# 4          1.025000

# %% [markdown]
# ### Normalizer

# %% [markdown]
# Sebenarnya untuk row

# %%
df_test['Price Norm'] = Normalizer().fit_transform(df_test[['Price']])
# Out:
# C:\Users\Admin\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df_test.head()
# Out:
#        Price  Distance  Car  Landsize  Rooms  Bedroom2  Bathroom  \
# 0  1480000.0       2.5  1.0     202.0      2       2.0       1.0
# 1  1035000.0       2.5  0.0     156.0      2       2.0       1.0
# 2  1465000.0       2.5  0.0     134.0      3       3.0       2.0
# 3   850000.0       2.5  1.0      94.0      3       3.0       2.0
# 4  1600000.0       2.5  2.0     120.0      4       3.0       1.0
#
#    Prize Std Scl  Price Std Scl 2  Price MinMax Sc  Price MaxAbs Scl  \
# 0       0.632448         0.632448         0.156478          0.164444
# 1      -0.063640        -0.063640         0.106562          0.115000
# 2       0.608984         0.608984         0.154795          0.162778
# 3      -0.353025        -0.353025         0.085810          0.094444
# 4       0.820157         0.820157         0.169938          0.177778
#
#    Price Robust Scl  Price Norm
# 0          0.848529         1.0
# 1          0.194118         1.0
# 2          0.826471         1.0
# ...

# %% [markdown]
# https://towardsdatascience.com/scale-standardize-or-normalize-with-scikit-learn-6ccc7d176a02
#
# https://medium.com/@rrfd/standardize-or-normalize-examples-in-python-e3f174b65dfc
#
# https://medium.com/predict/standardization-on-crazy-data-python-cd5b1282a97f

# %% [markdown]
# ## Tugas
#
# - Price adalah target, sehingga tidak perlu di scaling.
# - Sedangkan feature Distance, Car, Landsize, Rooms, Bedroom2, Bathroom adalah feature yang harus di-scaling.
# - Data NaN (meskipun bukan best practice) dihapus saat sudah menjadi df_test (sudah dipilih feature).
# - Gunakan Scaler yang sesuai dengan kondisi data. Cek outliers ada atau tidak.
# - Simpan ke dalam dataframe baru yang berisi target (Price) dan feature Distance, Car, Landsize, Rooms, Bedroom2, Bathroom yang sudah di scaling.

# %% [markdown]
# ## Step
#
# 1. Drop all missing value
# 2. Cek outliers tiap feature
# 3. Scaling sesuai kondisi feature
# 4. Simpan dalam df_ready
